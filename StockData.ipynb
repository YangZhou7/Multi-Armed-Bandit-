# %%
import matplotlib.pyplot as plt
import fix_yahoo_finance as yf  
data = yf.download('AAPL','2016-01-01','2018-06-01')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
close = data['Adj Close']
plt.plot(close)
